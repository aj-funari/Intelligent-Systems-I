# %% [markdown]
# # ENGR-E 221 Intelligent Systems I Fall 2020
#
# ## Lab 12 CNN algorithms
#
# Thursday Lab: 11/19/2020 3:15 pm - 4:30 pm
#
# Friday Lab: 11/20/2020 9:25 am - 10:40 am

# %% [markdown]
# ### Outline
#
#
# 1. Convolutional Neural Network
#
# 2. TensorFlow
#
# 3. Build and compile a CNN
#
#
#
#
# **NN Sources**
#
# * [NN 1](https://www.kdnuggets.com/2019/07/convolutional-neural-networks-python-tutorial-tensorflow-keras.html)
#
# * [NN 2](https://www.edureka.co/blog/convolutional-neural-network/)
#
# * [NN 3](https://victorzhou.com/blog/intro-to-cnns-part-1/)
#
# * [NN 4](https://towardsai.net/p/machine-learning/beginner-guides-to-convolutional-neural-network-from-scratch-kuzushiji-mnist-75f42c175b21)
#
#
#
# This is super usefull if you want to run within a browser: [NN 3 in the browser](https://repl.it/@vzhou842/A-CNN-from-scratch-Part-1#main.py)

# %% [markdown]
# ### Introduction  (15 minutes)
#
# The objective of lab 11 is to familiarize you with the Convolutional Neural Networks (CNN's), I have provided some useful resources about that showcase the implementation of these from scratch by defining classes, I suggest you take a look and remind yourself what the constructor is and how we create a class in python. We will go through some code and identify these to ensure you remember.
#
# This lab was recreated from the TensorFLow tutriols page found here: [TensorFlow Tutorials](https://www.tensorflow.org/tutorials/images/cnn)

# %% [markdown]
# ## Task 1 (45 minutes): Build and compile a CNN to use on the CIFAR-10 dataset.
#
# ```python
# import tensorflow as tf
#
# from tensorflow.keras import datasets, layers, models
# import matplotlib.pyplot as plt
#
# (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
#
# # Normalize pixel values to be between 0 and 1
# train_images, test_images = train_images / 255.0, test_images / 255.0
# ```
#
# We should be familar with what is happening here but discuss the division by 255.
#
#
# Now lets look at the images we just downloaded.
#
# ```python
# class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#                'dog', 'frog', 'horse', 'ship', 'truck']
#
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(train_images[i], cmap=plt.cm.binary)
#     # The CIFAR labels happen to be arrays,
#     # which is why you need the extra index
#     plt.xlabel(class_names[train_labels[i][0]])
# plt.show()
# ```
#
# Recall from lecture that a CNN takes input in the form of image_height, image_width and color_channels where color_channels refers to red, green blue. In this example with create our CNN to take inputs in the shape of (32,32,3). THe CIFAR-10 dataset is descibed here: [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html). From this you will see why we picked 32 for height and width. Defining our input shape is done by passing the input_shape argument to our first layer.
#
# ```python
# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.summary()
# ```
#
# In order to complete the model we wil funnel the last ouput layer (in our case of shape (4,4,64)) into atleast one dense layer in order to perform classification. In CNN's the Dense layer takes a vector as input and our current output is a 3-dimensional array. We first need to flatten the 3D output to a 1D vector then add one or more dense layers on top. As the CIFAR-10 dataset has 10 classes we will uses a final Dense layer with 10 outputs and a softmax activation.
#
# ```python
# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(10))
# model.summary()
# ```
#
# How many dense layers does our output go through and what is the new length of our output? '
#
# ```python
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])
#
# history = model.fit(train_images, train_labels, epochs=10,
#                     validation_data=(test_images, test_labels))
# ```
#
# Now the evalution of our model.
#
# ```python
# plt.plot(history.history['accuracy'], label='accuracy')
# plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
# plt.legend(loc='lower right')
#
# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# ```
#
#
# Just print the test accruacy.
#
# ```python
# print(test_acc)
# ```

# %%
# Task 1
